# %% [markdown]
# # BASEBALL WINNING PREDICTION

# %% [markdown]
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %% [markdown]
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, and Errors
#
# -- Output: Number of predicted wins (W)

# %%
#importing required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
#read data set
df=pd.read_csv("baseball.csv")

# %%
#checking dataset
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
#checking data shape
df.shape
# Out:
# (30, 17)

# %%
#checking the columns heading
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
#see info of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# # EDA

# %%
sns.heatmap(df.isnull())

# %%
#lets check whether the null values are present in the dataset or not using heatmap
sns.heatmap(df.isnull(),annot=True)
plt.show()

# %%
#null values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
#checking correlation
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.plot(kind='box',subplots=True,layout=(2,9))
# Out:
# W         AxesSubplot(0.125,0.536818;0.0731132x0.343182)
# R      AxesSubplot(0.212736,0.536818;0.0731132x0.343182)
# AB     AxesSubplot(0.300472,0.536818;0.0731132x0.343182)
# H      AxesSubplot(0.388208,0.536818;0.0731132x0.343182)
# 2B     AxesSubplot(0.475943,0.536818;0.0731132x0.343182)
# 3B     AxesSubplot(0.563679,0.536818;0.0731132x0.343182)
# HR     AxesSubplot(0.651415,0.536818;0.0731132x0.343182)
# BB     AxesSubplot(0.739151,0.536818;0.0731132x0.343182)
# SO     AxesSubplot(0.826887,0.536818;0.0731132x0.343182)
# SB           AxesSubplot(0.125,0.125;0.0731132x0.343182)
# RA        AxesSubplot(0.212736,0.125;0.0731132x0.343182)
# ER        AxesSubplot(0.300472,0.125;0.0731132x0.343182)
# ERA       AxesSubplot(0.388208,0.125;0.0731132x0.343182)
# CG        AxesSubplot(0.475943,0.125;0.0731132x0.343182)
# SHO       AxesSubplot(0.563679,0.125;0.0731132x0.343182)
# SV        AxesSubplot(0.651415,0.125;0.0731132x0.343182)
# ...

# %%
collist=df.columns.values

# %%
ncol=12
nrows=10

# %%
plt.figure(figsize=(ncol,5*ncol))
for i in range(1, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# # to check distribution of skewness

# %%
#plt.figure(figsize=(5*totalcol,5*totalcol))
plt.figure(figsize=(16,16))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(df[collist[i]])

# %% [markdown]
# the distribution is normal

# %%
sns.pairplot(df)

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# # Removing outliers

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
#row column
z[13][8]
# Out:
# 0.8606536207726614

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %% [markdown]
# # Featuring

# %%
#Now Let separate input and output variable to be used for the Linear regression problem

X=df[['R','AB','H','2B','3B','HR','BB','SO','SB','RA','ER','ERA','CG','SHO','SV','E']]
y=df[['W']]

# %%
#scaling down using standardscaler

from sklearn.preprocessing import StandardScaler
S=StandardScaler()
x=sc.fit_transform(X)
x
# Out:
# array([[ 0.61907797,  0.84773126,  1.66368512,  1.42017307,  1.04119304,
#         -0.7872986 , -1.53490242, -2.69762957,  0.91388329, -0.66623393,
#         -0.50511008, -0.50695519, -0.5398062 , -0.81462859,  1.67160651,
#         -0.46146963],
#        [ 0.13443166, -0.71109353, -0.97068076,  0.12740339,  1.23580856,
#         -0.24396668, -0.5365919 ,  0.15487844, -0.60182558,  0.16597077,
#          0.24892985,  0.25459752, -0.5398062 ,  0.1728    ,  0.24987932,
#         -0.60719689],
#        [-0.33290586, -1.1152333 , -0.15189137,  1.58879521, -0.22380785,
#         -0.7233772 ,  1.13914361, -0.89398189,  0.11144918, -0.68033909,
#         -0.75162313, -0.64134684,  2.77264091, -0.32091429, -0.65485616,
#         -1.11724227],
#        [-1.14641931,  0.24152162, -0.40108814, -0.82812203, -0.41842337,
#         -0.8831807 , -1.16053598, -0.16860185, -0.69098493,  0.18007593,
#          0.10392217,  0.05301004,  1.3004422 , -0.56777144, -0.78410408,
#          0.48575751],
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
max_r_score=0
for r_state in range(42,101):
    X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=r_state,test_size=0.20)
    regr=linear_model.LinearRegression()
    regr.fit(X_train,y_train)
    y_pred=regr.predict(X_test)
    r2_scr=r2_score(y_test,y_pred)
    print("r2_score corressponnding to random state: ",r_state,"is:",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
        
print()
print()
print("max r2_score correspnding to random state  ",final_r_state,"is",max_r_score)
# Out:
# r2_score corressponnding to random state:  42 is: 0.7876400316149446
# r2_score corressponnding to random state:  43 is: -1.0543428896604752
# r2_score corressponnding to random state:  44 is: 0.5894992447123721
# r2_score corressponnding to random state:  45 is: 0.6385651240924294
# r2_score corressponnding to random state:  46 is: 0.6261439472974861
# r2_score corressponnding to random state:  47 is: 0.8116559418363234
# r2_score corressponnding to random state:  48 is: 0.8234694071796368
# r2_score corressponnding to random state:  49 is: -0.07399772649633274
# r2_score corressponnding to random state:  50 is: 0.6111709711671869
# r2_score corressponnding to random state:  51 is: 0.4582745176586478
# r2_score corressponnding to random state:  52 is: 0.5097793692109345
# r2_score corressponnding to random state:  53 is: 0.2550058206707292
# r2_score corressponnding to random state:  54 is: 0.7551746347340793
# r2_score corressponnding to random state:  55 is: 0.7860903369149369
# ...

# %%
best_score=0
for i in range(201):
    from sklearn.model_selection import train_test_split
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=i)
    from sklearn.preprocessing import StandardScaler
    sc_x=StandardScaler()
    #sc_y=StandardScaler()
    X_train=sc_x.fit_transform(X_train)
    #y_train=sc_y.fit_transform(y_train)
    lr=LinearRegression()
    lr.fit(X_train,y_train)
    b_score=lr.score(sc_x.transform(X_test),y_test)
    if b_score>best_score:
        best_score=b_score
        random_state=i
print('Best Score={} for random state={}'.format(best_score*100,random_state))
# Out:
# Best Score=93.43338116280448 for random state=165

# %%
X_tarin,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=165)
sc_X=StandardScaler()
X_tarin=sc.fit_transform(X_train)

from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
y_pred=lr.predict(X_test)

# %%
#lets find ut the cross valdiation score
from sklearn.model_selection import cross_val_score
cross_val_score(linear_model.LinearRegression(),X,y,cv=5,scoring='r2').mean()
# Out:
# 0.04075540667465847

# %%
y_pred=lr.predict(sc_x.transform(X_test))

# %%
#lets evaluate the RMSE and r2 score using sklearn library
print("r2 score is={}".format(r2_score(y_test,y_pred)*100))
print("RMSE is={} ".format(mean_squared_error(y_test,y_pred)))
print('The MSE ={}'.format(mean_squared_error(y_test, y_pred)))
print('The MAE ={}'.format(mean_absolute_error(y_test, y_pred)))
# Out:
# r2 score is=-52.45765807308062
# RMSE is=224.32450411475224
# The MSE =224.32450411475224
# The MAE =10.945824027452389
